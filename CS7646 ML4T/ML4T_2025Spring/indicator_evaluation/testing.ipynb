# %%
from indicators import test_code, get_indicators

# %%
import pandas as pd
import numpy as np
od2 = pd.read_csv("/Users/srinadh.nidadana-c/Documents/Academics/GTechMasters/CS7646 ML4T/ML4T_2025Spring/marketsim/orders/orders-02.csv")

# %%
od2
# Out:
#           Date Symbol Order  Shares
# 0   2011-01-10   AAPL   BUY    1500
# 1   2011-01-10   AAPL  SELL    1500
# 2   2011-01-13   AAPL  SELL    1500
# 3   2011-01-13    IBM   BUY    4000
# 4   2011-01-26   GOOG   BUY    1000
# 5   2011-02-02    XOM  SELL    4000
# 6   2011-02-10    XOM   BUY    4000
# 7   2011-03-03   GOOG  SELL    1000
# 8   2011-06-03    IBM  SELL    3300
# 9   2011-05-03    IBM   BUY    1500
# 10  2011-06-10   AAPL   BUY    1200
# 11  2011-08-01   GOOG   BUY      55
# 12  2011-08-01   GOOG  SELL      55
# 13  2011-08-01   GOOG   BUY      55
# 14  2011-12-20   AAPL  SELL    1200
# 15  2011-12-21   AAPL   BUY      20
# 16  2011-12-28    IBM  SELL    2200

# %%
jpm = pd.read_csv("/Users/srinadh.nidadana-c/Documents/Academics/GTechMasters/CS7646 ML4T/ML4T_2025Spring/data/JPM.csv")
jpm
# Out:
#             Date   Open   High    Low  Close    Volume  Adj Close
# 0     2012-09-12  39.88  40.25  39.79  39.92  29882200      39.92
# 1     2012-09-11  38.80  39.63  38.73  39.60  22378900      39.60
# 2     2012-09-10  39.23  39.78  38.73  38.76  20853500      38.76
# 3     2012-09-07  39.04  39.53  39.00  39.30  28082400      39.30
# 4     2012-09-06  37.58  38.87  37.50  38.69  41346800      38.69
# ...          ...    ...    ...    ...    ...       ...        ...
# 3170  2000-02-07  82.19  83.37  81.75  82.19   4684200      37.37
# 3171  2000-02-04  82.50  83.31  81.56  81.75   5115100      37.17
# 3172  2000-02-03  83.50  84.87  80.25  83.19   9200200      37.82
# 3173  2000-02-02  83.00  84.19  81.37  82.37   7126200      37.45
# 3174  2000-02-01  82.44  84.50  81.31  83.75   9651000      38.08
#
# [3175 rows x 7 columns]

# %%
jpm['Date'] = pd.to_datetime(jpm['Date'])

# %%
jpm['Date'].dt.year.value_counts()
# Out:
# 2008    253
# 2011    252
# 2010    252
# 2009    252
# 2005    252
# 2004    252
# 2003    252
# 2002    252
# 2007    251
# 2006    251
# 2001    248
# 2000    232
# 2012    176
# Name: Date, dtype: int64

# %%
jpm.loc[jpm['Date'].dt.year== 2008, 'Date'].nunique(), jpm.loc[jpm['Date'].dt.year== 2008, 'Date'].nunique()
# Out:
# (253, 253)

# %%
jpm.loc[jpm['Date'].dt.year== 2008, 'Date'].unique()
# Out:
# array(['2008-12-31T00:00:00.000000000', '2008-12-30T00:00:00.000000000',
#        '2008-12-29T00:00:00.000000000', '2008-12-26T00:00:00.000000000',
#        '2008-12-24T00:00:00.000000000', '2008-12-23T00:00:00.000000000',
#        '2008-12-22T00:00:00.000000000', '2008-12-19T00:00:00.000000000',
#        '2008-12-18T00:00:00.000000000', '2008-12-17T00:00:00.000000000',
#        '2008-12-16T00:00:00.000000000', '2008-12-15T00:00:00.000000000',
#        '2008-12-12T00:00:00.000000000', '2008-12-11T00:00:00.000000000',
#        '2008-12-10T00:00:00.000000000', '2008-12-09T00:00:00.000000000',
#        '2008-12-08T00:00:00.000000000', '2008-12-05T00:00:00.000000000',
#        '2008-12-04T00:00:00.000000000', '2008-12-03T00:00:00.000000000',
#        '2008-12-02T00:00:00.000000000', '2008-12-01T00:00:00.000000000',
#        '2008-11-28T00:00:00.000000000', '2008-11-26T00:00:00.000000000',
#        '2008-11-25T00:00:00.000000000', '2008-11-24T00:00:00.000000000',
# ...

# %%
https://gatech.instructure.com/courses/422786/files/56645589?wrap=1
https://gatech.instructure.com/courses/422786/files/56645703?wrap=1
https://gatech.instructure.com/courses/422786/files/56645705?wrap=1
